# %% [markdown]
# <a href="https://colab.research.google.com/github/harivign/churn-prediction-in-banking-by-deeplearning/blob/main/churn_prediction_in_banking_by_deeplearn_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #churn prediction in banking by deeplearning approach

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Churn_Predictions.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.drop(columns=["RowNumber","CustomerId","Surname"],inplace=True)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
#finding unique for object columns
for i in df.columns:
  if df[i].dtypes=="object":
    print(i,df[i].unique())
# Out:
# Geography ['France' 'Spain' 'Germany']
# Gender ['Female' 'Male']

# %%
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
import pickle

# %%
encoder1=OrdinalEncoder().fit(df[["Geography"]])
df["Geography"]=encoder1.transform(df[["Geography"]])
with open("encoder_geography.pkl","wb") as f:
  pickle.dump(encoder1,f)

# %%
encoder2=OrdinalEncoder().fit(df[["Gender"]])
df["Gender"]=encoder2.transform(df[["Gender"]])
with open("encoder_gender.pkl","wb") as f:
  pickle.dump(encoder2,f)

# %%
df
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619        0.0     0.0   42       2       0.00              1
# 1             608        2.0     0.0   41       1   83807.86              1
# 2             502        0.0     0.0   42       8  159660.80              3
# 3             699        0.0     0.0   39       1       0.00              2
# 4             850        2.0     0.0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771        0.0     1.0   39       5       0.00              2
# 9996          516        0.0     1.0   35      10   57369.61              1
# 9997          709        0.0     0.0   36       7       0.00              1
# 9998          772        1.0     1.0   42       3   75075.31              2
# 9999          792        0.0     0.0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df.corr()
# Out:
#                  CreditScore  Geography    Gender       Age    Tenure  \
# CreditScore         1.000000   0.007888 -0.002857 -0.003965  0.000842
# Geography           0.007888   1.000000  0.004719  0.022812  0.003739
# Gender             -0.002857   0.004719  1.000000 -0.027544  0.014733
# Age                -0.003965   0.022812 -0.027544  1.000000 -0.009997
# Tenure              0.000842   0.003739  0.014733 -0.009997  1.000000
# Balance             0.006268   0.069408  0.012087  0.028308 -0.012254
# NumOfProducts       0.012238   0.003972 -0.021859 -0.030680  0.013444
# HasCrCard          -0.005458  -0.008523  0.005766 -0.011721  0.022583
# IsActiveMember      0.025651   0.006724  0.022544  0.085472 -0.028362
# EstimatedSalary    -0.001384  -0.001369 -0.008112 -0.007201  0.007784
# Exited             -0.027094   0.035943 -0.106512  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
#hypotheses

continues=["CreditScore","Tenure","Balance","NumOfProducts","EstimatedSalary","Age","Exited"]
categories=["Geography","Gender","HasCrCard","IsActiveMember"]

from scipy import stats

def two_sample(d1,d2):
  t=0
  f=0
  for i in  range(31):
    sample1=d1.sample(frac=0.03)
    sample2=d2.sample(frac=0.03)
    t_test,p_value=stats.ttest_ind(sample1,sample2)
    if p_value < 0.055:
      f=f+1
    else:
      t=t+1
  if t>f:
    return True
  else:
    return False

#defining function for categories vs categories
def chisqare_cat_vs_cat(d1,d2):
  return True if stats.chi2_contingency(pd.crosstab(d1,d2))[1] < 0.055 else False

def annova_test(d1,d2):
  group=df[d2].unique()
  data={}
  for i in group:
    data[i]=df[d1][df[d2]==i]
  f_value,p_value=stats.f_oneway(*[i for i in data.values()])  #task for baby
  if p_value < 0.055:
    return False
  else:
    return True

final={}
for i in df.columns:
  final[i]={}
  for j in df.columns:
    if (i in continues) and (j in continues):
      result=two_sample(df[i],df[j])
    elif  (i in continues) and (j in categories):
      result=annova_test(i,j)
    elif (i in categories) and (j in continues):
      result=annova_test(j,i)
    elif (i in categories) and (j in categories):
      result=chisqare_cat_vs_cat(df[i],df[j])
    if result:
      final[i][j]=1
    else:
      final[i][j]=0

# %%
df1=pd.DataFrame(final)
df1
# Out:
#                  CreditScore  Geography  Gender  Age  Tenure  Balance  \
# CreditScore                1          1       1    0       0        0
# Geography                  1          1       1    0       1        0
# Gender                     1          1       1    0       1        1
# Age                        0          0       0    1       0        0
# Tenure                     0          1       1    0       1        0
# Balance                    0          0       1    0       0        1
# NumOfProducts              0          1       0    0       0        0
# HasCrCard                  1          0       0    1       0        1
# IsActiveMember             0          0       1    0       0        1
# EstimatedSalary            0          1       1    0       0        0
# Exited                     0          0       0    0       0        0
#
#                  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
for i in continues:
  print(i,df[i].skew(),df[i].kurtosis())
# Out:
# CreditScore -0.07160660820092675 -0.42572568480291295
# Tenure 0.01099145797717904 -1.1652252274891766
# Balance -0.14110871094154384 -1.489411767941925
# NumOfProducts 0.7455678882823168 0.5829807629457178
# EstimatedSalary 0.0020853576615585162 -1.1815184473915485
# Age 1.0113202630234552 1.3953470615086956
# Exited 1.4716106649378211 0.16567104336407112

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x=df.drop("Exited",axis=1)
y=df["Exited"]

# %%
from tensorflow.keras.utils import to_categorical
y_new=to_categorical(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y_new,test_size=0.2,random_state=1)

# %%
x_train_scaler=scaler.fit_transform(x_train)
x_test_scaler=scaler.transform(x_test)

# %%
import tensorflow as tf

# %%
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential

import tensorflow as tf
model=Sequential()
model.add(Dense(1024,input_dim=x_train_scaler.shape[1],activation=tf.keras.layers.LeakyReLU(alpha=0.2)))
model.add(Dropout(0.2))
model.add(Dense(512,activation=tf.keras.layers.LeakyReLU(alpha=0.2)))
model.add(Dropout(0.23))
model.add(Dense(256,activation=tf.keras.layers.LeakyReLU(alpha=0.2)))
model.add(Dropout(0.15))
model.add(Dense(64,activation=tf.keras.layers.LeakyReLU(alpha=0.2)))
model.add(Dense(32,activation=tf.keras.layers.LeakyReLU(alpha=0.2)))
model.add(Dense(2,activation="softmax"))
model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy",tf.keras.metrics.F1Score(),tf.keras.metrics.Recall(),tf.keras.metrics.Precision()])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 1024)                │          11,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 512)                 │               0 │
# ...

# %%
x_train_scaler.shape
# Out:
# (8000, 10)

# %%
x_train_scaler.shape[1]
# Out:
# 10

# %%
x_test.shape
# Out:
# (2000, 10)

# %%
y_test.shape
# Out:
# (2000, 2)

# %%
x_test_scaler.shape
# Out:
# (2000, 10)

# %%
result=model.fit(x_train_scaler,y_train,epochs=45,validation_data=(x_test_scaler, y_test),batch_size=32)
# Out:
# Epoch 1/45
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - accuracy: 0.8790 - f1_score: 0.7882 - loss: 0.2903 - precision_1: 0.8790 - recall_1: 0.8790 - val_accuracy: 0.8665 - val_f1_score: 0.7765 - val_loss: 0.3571 - val_precision_1: 0.8665 - val_recall_1: 0.8665
# Epoch 2/45
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.8821 - f1_score: 0.7788 - loss: 0.2819 - precision_1: 0.8821 - recall_1: 0.8821 - val_accuracy: 0.8705 - val_f1_score: 0.7745 - val_loss: 0.3549 - val_precision_1: 0.8705 - val_recall_1: 0.8705
# Epoch 3/45
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8849 - f1_score: 0.7950 - loss: 0.2833 - precision_1: 0.8849 - recall_1: 0.8849 - val_accuracy: 0.8665 - val_f1_score: 0.7532 - val_loss: 0.3672 - val_precision_1: 0.8665 - val_recall_1: 0.8665
# Epoch 4/45
# ...

# %%
pickle.dump(result,open("result.pkl","wb"))

# %%
model.save("result.h5", save_format="h5")
